# %%
import skrf as rf

# %%
simulados = rf.Network('./simulaciones/Parametros_S_Simulados.s2p')
medidos = rf.Network('./mediciones/Parametros_S_Medidos.s2p')

# %%
simulados.plot_s_db()

# %%
simulados.s_vswr
# Out:
# array([[[2.55022233, 1.12723413],
#         [1.12721987, 2.42479828]],
#
#        [[2.54706153, 1.12714272],
#         [1.12712847, 2.42216709]],
#
#        [[2.54390006, 1.12705427],
#         [1.12704024, 2.41953994]],
#
#        ...,
#
#        [[3.29196523, 1.6464373 ],
#         [1.64723946, 3.1199312 ]],
#
#        [[3.29975298, 1.64721844],
#         [1.64802107, 3.12711515]],
#
#        [[3.30755049, 1.64799302],
#         [1.64879612, 3.1343071 ]]], shape=(1001, 2, 2))

# %%
medidos.plot_s_db()
